# %% [markdown]
# # 3.3 $\quad$ CVXPY

# %% [markdown]
# Para la resolución de problemas de optimización convexa en python existen básicamente 3 métodos:
#
# - Implementación de los distintos algoritmos de optimización (solvers), como, por ejemplo, Gurovi, Scipy PuLP, GLPK, CPLEX, etc.
#
# - Diseño de tu propio algoritmo (modelos de Machine Learning).
#
# - Usar una librería de alto nivel (CVXPY), que integra los solvers estandar usando un lenguaje de alto nivel.

# %% [markdown]
# CVXPY es un lenguaje específico para la optimización convexa integrado en Python. Sus características principales incluyen:
#
# - **Expresión Natural de Problemas**:
#   - Permite a los usuarios formular problemas de optimización convexa utilizando una sintaxis de alto nivel que sigue la lógica matemática.
#
# - **Compatibilidad con Solucionadores Conocidos**:
#   - Facilita el uso de los solvers de optimización más conocidos
#
# - **Verifica que el problema es convexo**:
#   - La librería tiene herramientas para comprobar si el problema de optimización es convexo.

# %% [markdown]
# Puedes encontrar toda la documentación sobre la librería en [CVXPY](https://www.cvxpy.org/index.html)
#
# Presentación de [Convex Optimization with CVXPY](https://www.youtube.com/watch?v=kXqu-TqEl7Q)

# %% [markdown]
# ### Discipline Convex Programming
#
# #### Concepto y Fundamentos
# - **Definición**: Disciplined Convex Programming (DCP) es un sistema de reglas y técnicas para la construcción de problemas de optimización convexa.
# - **Objetivo**: Asegurar la convexidad de los problemas de optimización formulados, facilitando la búsqueda de soluciones globales óptimas.
#
# #### Principios Clave
# 1. **Composición de Funciones Convexas**: Las funciones en un problema DCP deben combinarse de acuerdo con ciertas reglas que preservan la convexidad.
# 2. **Reglas de Curvatura**: Identifican si una expresión es convexa, cóncava o afín, basándose en la operación y las funciones involucradas.
# 3. **Restricciones DCP**: Solo ciertas formas de restricciones son permitidas para mantener la convexidad del problema.
#
# #### Aplicación en CVXPY
# - **CVXPY y DCP**: CVXPY utiliza DCP para verificar automáticamente la convexidad de un problema formulado.
# - **Beneficios**:
#   - Simplifica la formulación de problemas convexos.
#   - Evita errores comunes al garantizar que el problema es convexo y, por lo tanto, solucionable.

# %% [markdown]
# ### Componentes de un Problema de Optimización usando CVXPY
#
# Recuerda lo que hemos visto en el notebook anterior:
#
# Nuestro objetivo es **mimimizar/maximizar $f_0(x| \theta)$** sujeto a $f_i(x| \theta) \leq b_i$,   $\qquad i= 1,...,m$
#
# donde:
#
# - $x = (x_1, x_2,..., x_n)$ son las variables
#
# - $\theta = (\theta_1, \theta_2,..., \theta_n)$ son los parámetros
#
# - $f_0: \mathbb{R}^n \rightarrow \mathbb{R}$  es la función objetivo
#
# - $f_i: \mathbb{R}^n \rightarrow \mathbb{R}$ son las restricciones

# %%
import numpy as np
import pandas as pd
import cvxpy as cp
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pventura\AppData\Local\Temp\ipykernel_31196\3464941646.py", line 3, in <module>
#     import cvxpy as cp
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\__init__.py", line 56, in <module>
#     from cvxpy.problems.problem import Problem as Problem
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\problems\problem.py", line 38, in <module>
#     from cvxpy.reductions import InverseData
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\__init__.py", line 31, in <module>
#     from cvxpy.reductions.solvers.solving_chain import SolvingChain
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py", line 43, in <module>
#     from cvxpy.reductions.solvers import defines as slv_def
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\defines.py", line 121, in <module>
#     INSTALLED_SOLVERS = installed_solvers()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\defines.py", line 110, in installed_solvers
#     if solver.is_installed():
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\solver.py", line 59, in is_installed
#     self.import_solver()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\conic_solvers\xpress_conif.py", line 63, in import_solver
#     import xpress
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\xpress\__init__.py", line 103, in <module>
#     import xpresslib as _xpresslib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# C:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\Lib\site-packages\xpress\lib
# c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\Scripts
# C:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\Scripts
# C:\Program Files (x86)\Common Files\Oracle\Java\java8path
# C:\Program Files (x86)\Common Files\Oracle\Java\javapath
# C:\Python312\Scripts\
# C:\Python312\
# C:\oracle\product\11.2.0\client_1\bin
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.6\bin
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.6\libnvvp
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.2\bin
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.2\libnvvp
# C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\wbin
# C:\oracle\product\12.2.0\client_1\bin
# C:\Program Files\Microsoft MPI\Bin\
# C:\Windows\system32
# C:\Windows
# C:\Windows\System32\Wbem
# C:\Windows\System32\WindowsPowerShell\v1.0\
# C:\Windows\System32\OpenSSH\
# C:\Program Files\AutoFirma\AutoFirma
# C:\Program Files (x86)\Sybase\Shared\PowerBuilder\
# c:\rd\rd_oracle\bin
# C:\Program Files\dotnet\
# C:\Program Files\Microsoft SQL Server\130\Tools\Binn\
# C:\Program Files (x86)\Microsoft SQL Server\150\DTS\Binn\
# c:\archivos de programa\Sybase\Shared\PowerBuilder
# C:\Program Files (x86)\Sybase\Shared\PowerBuilder
# C:\WINDOWS\system32
# C:\WINDOWS
# C:\WINDOWS\System32\Wbem
# C:\WINDOWS\System32\WindowsPowerShell\v1.0\
# C:\WINDOWS\System32\OpenSSH\
# C:\Program Files (x86)\M
# C:\Program Files\PuTTY\
# C:\Program Files (x86)\Google\Cloud SDK\google-cloud-sdk\bin
# C:\Program Files\Microsoft VS Code\bin
# C:\Program Files\Microsoft SQL Server\Client SDK\ODBC\170\Tools\Binn\
# C:\WINDOWS\system32
# C:\WINDOWS
# C:\WINDOWS\System32\Wbem
# C:\WINDOWS\System32\WindowsPowerShell\v1.0\
# C:\WINDOWS\System32\OpenSSH\
# C:\Program Files\Amazon\AWSCLI\bin\
# C:\Program Files\Azure Data Studio\bin
# C:\Program Files\Git\cmd
# C:\Program Files\Graphviz\bin
# C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common
# C:\Program Files\NVIDIA Corporation\NVIDIA NvDLISR
# C:\Program Files\Microsoft SQL Server\150\Tools\Binn\
# C:\Program Files\NVIDIA Corporation\Nsight Compute 2022.1.1\
# C:\Program Files (x86)\Microsoft SQL Server\160\DTS\Binn\
# C:\ProgramData\chocolatey\bin
# C:\Program Files\Pandoc\
# C:\Program Files\Microsoft SQL Server\130\DTS\Binn\
# C:\Program Files\Microsoft SQL Server\140\DTS\Binn\
# C:\Program Files\Microsoft SQL Server\150\DTS\Binn\
# C:\Program Files\Microsoft SQL Server\160\DTS\Binn\
# C:\Program Files\Docker\Docker\resources\bin
# C:\Users\pventura\.local\bin
# C:\Users\pventura\.pyenv\pyenv-win\bin
# C:\Users\pventura\.pyenv\pyenv-win\shims
# C:\Users\pventura\AppData\Local\Microsoft\WindowsApps
# C:\Users\pventura\.dotnet\tools
# C:\Users\pventura\AppData\Roaming\TinyTeX\bin\win32
# C:\Users\pventura\AppData\Local\GitHubDesktop\bin
# C:\Program Files\Fiddler
# C:\Program Files\Azure Data Studio\bin
# C:\Users\pventura\.dotnet\tools
# C:\Program Files\mongosh-1.0.4-win32-x64\bin
# C:\Users\pventura\AppData\Local\Microsoft\WindowsApps
# C:\Program Files\Azure Data Studio\bin
# C:\ProgramData\chocolatey\lib\Git-TF\Tools\git-tf-2.0.3.20131219
# C:\tools\gittfs
# C:\Users\pventura\.dotnet\tools
# C:\Users\pventura\AppData\Local\Programs\Microsoft VS Code Insiders\bin
# C:\Program Files\poppler-24.08.0\Library\bin
# C:\Program Files\Tesseract-OCR
#
# C:\Users\pventura\AppData\Local\Programs\Ollama
# (CVXPY) Mar 13 10:04:02 AM: Encountered unexpected exception importing solver XPRESS:
# ImportError('numpy.core.multiarray failed to import')
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "C:\Users\pventura\AppData\Roaming\uv\python\cpython-3.10.6-windows-x86_64-none\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pventura\AppData\Local\Temp\ipykernel_31196\3464941646.py", line 3, in <module>
#     import cvxpy as cp
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\__init__.py", line 56, in <module>
#     from cvxpy.problems.problem import Problem as Problem
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\problems\problem.py", line 38, in <module>
#     from cvxpy.reductions import InverseData
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\__init__.py", line 31, in <module>
#     from cvxpy.reductions.solvers.solving_chain import SolvingChain
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\solving_chain.py", line 43, in <module>
#     from cvxpy.reductions.solvers import defines as slv_def
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\defines.py", line 121, in <module>
#     INSTALLED_SOLVERS = installed_solvers()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\defines.py", line 114, in installed_solvers
#     if solver.is_installed():
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\solver.py", line 59, in is_installed
#     self.import_solver()
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\cvxpy\reductions\solvers\qp_solvers\xpress_qpif.py", line 27, in import_solver
#     import xpress  # noqa F401
#   File "c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\lib\site-packages\xpress\__init__.py", line 103, in <module>
#     import xpresslib as _xpresslib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# C:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\Lib\site-packages\xpress\lib
# C:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\Lib\site-packages\xpress\lib
# c:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\Scripts
# C:\WorkingFolderPersonal\microcredencial-carteras-python\.venv\Scripts
# C:\Program Files (x86)\Common Files\Oracle\Java\java8path
# C:\Program Files (x86)\Common Files\Oracle\Java\javapath
# C:\Python312\Scripts\
# C:\Python312\
# C:\oracle\product\11.2.0\client_1\bin
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.6\bin
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.6\libnvvp
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.2\bin
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.2\libnvvp
# C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\wbin
# C:\oracle\product\12.2.0\client_1\bin
# C:\Program Files\Microsoft MPI\Bin\
# C:\Windows\system32
# C:\Windows
# C:\Windows\System32\Wbem
# C:\Windows\System32\WindowsPowerShell\v1.0\
# C:\Windows\System32\OpenSSH\
# C:\Program Files\AutoFirma\AutoFirma
# C:\Program Files (x86)\Sybase\Shared\PowerBuilder\
# c:\rd\rd_oracle\bin
# C:\Program Files\dotnet\
# C:\Program Files\Microsoft SQL Server\130\Tools\Binn\
# C:\Program Files (x86)\Microsoft SQL Server\150\DTS\Binn\
# c:\archivos de programa\Sybase\Shared\PowerBuilder
# C:\Program Files (x86)\Sybase\Shared\PowerBuilder
# C:\WINDOWS\system32
# C:\WINDOWS
# C:\WINDOWS\System32\Wbem
# C:\WINDOWS\System32\WindowsPowerShell\v1.0\
# C:\WINDOWS\System32\OpenSSH\
# C:\Program Files (x86)\M
# C:\Program Files\PuTTY\
# C:\Program Files (x86)\Google\Cloud SDK\google-cloud-sdk\bin
# C:\Program Files\Microsoft VS Code\bin
# C:\Program Files\Microsoft SQL Server\Client SDK\ODBC\170\Tools\Binn\
# C:\WINDOWS\system32
# C:\WINDOWS
# C:\WINDOWS\System32\Wbem
# C:\WINDOWS\System32\WindowsPowerShell\v1.0\
# C:\WINDOWS\System32\OpenSSH\
# C:\Program Files\Amazon\AWSCLI\bin\
# C:\Program Files\Azure Data Studio\bin
# C:\Program Files\Git\cmd
# C:\Program Files\Graphviz\bin
# C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common
# C:\Program Files\NVIDIA Corporation\NVIDIA NvDLISR
# C:\Program Files\Microsoft SQL Server\150\Tools\Binn\
# C:\Program Files\NVIDIA Corporation\Nsight Compute 2022.1.1\
# C:\Program Files (x86)\Microsoft SQL Server\160\DTS\Binn\
# C:\ProgramData\chocolatey\bin
# C:\Program Files\Pandoc\
# C:\Program Files\Microsoft SQL Server\130\DTS\Binn\
# C:\Program Files\Microsoft SQL Server\140\DTS\Binn\
# C:\Program Files\Microsoft SQL Server\150\DTS\Binn\
# C:\Program Files\Microsoft SQL Server\160\DTS\Binn\
# C:\Program Files\Docker\Docker\resources\bin
# C:\Users\pventura\.local\bin
# C:\Users\pventura\.pyenv\pyenv-win\bin
# C:\Users\pventura\.pyenv\pyenv-win\shims
# C:\Users\pventura\AppData\Local\Microsoft\WindowsApps
# C:\Users\pventura\.dotnet\tools
# C:\Users\pventura\AppData\Roaming\TinyTeX\bin\win32
# C:\Users\pventura\AppData\Local\GitHubDesktop\bin
# C:\Program Files\Fiddler
# C:\Program Files\Azure Data Studio\bin
# C:\Users\pventura\.dotnet\tools
# C:\Program Files\mongosh-1.0.4-win32-x64\bin
# C:\Users\pventura\AppData\Local\Microsoft\WindowsApps
# C:\Program Files\Azure Data Studio\bin
# C:\ProgramData\chocolatey\lib\Git-TF\Tools\git-tf-2.0.3.20131219
# C:\tools\gittfs
# C:\Users\pventura\.dotnet\tools
# C:\Users\pventura\AppData\Local\Programs\Microsoft VS Code Insiders\bin
# C:\Program Files\poppler-24.08.0\Library\bin
# C:\Program Files\Tesseract-OCR
#
# C:\Users\pventura\AppData\Local\Programs\Ollama
# (CVXPY) Mar 13 10:04:12 AM: Encountered unexpected exception importing solver XPRESS:
# ImportError('numpy.core.multiarray failed to import')

# %% [markdown]
# #### Variables de decisión (parámetros entrenables)
# - **Definición**: Representan las cantidades que queremos optimizar. Representadas por el vector $w$.
# - **Ejemplo**: En un problema de asignación de recursos, las variables podrían ser la cantidad de recursos asignados a diferentes tareas.

# %% [markdown]
# Para recordarlo, puedes entender el concepto de `variable` como algo que se va a modificar (va a variar) durante el ajuste del optimizador.

# %%
# Una variable entrenable de 2 componentes (2 ponderaciones)
w = cp.Variable(2)  # (w1, w2)
w
# Out:
# Variable((2,), var1)

# %%
# Es equivalente a definir directamente un vector de variables (5 ponderaciones)
w = cp.Variable((5,))  # (w1, w2, w3, w4, w5)
w
# Out:
# Variable((5,), var2)

# %%
# También es posible definir una matriz de variables
m = cp.Variable((5, 2))
m
# [(m11, m12),
#  (m21, m22),
#  (m31, m32),
#  (m41, m42),
#  (m51, m52)]
# Out:
# Variable((5, 2), var3)

# %% [markdown]
# #### Función Objetivo
# - **Definición**: Es la función que queremos minimizar o maximizar. Representada por $f_0$.
# - **Ejemplo**: En un problema de minimización de costos, la función objetivo podría ser el costo total en función de las variables de decisión.

# %%
# Minimizamos la suma de las componentes del vector v
cp.Minimize(cp.sum(w))
# Out:
# Minimize(Expression(AFFINE, UNKNOWN, ()))

# %%
# Minimizamos la norma L1 (suma de valores absolutos) del vector a
cp.Minimize(cp.norm(w, 1))
# Out:
# Minimize(Expression(CONVEX, NONNEGATIVE, ()))

# %%
# Maximizamos la suma de los logaritmos de las componentes del vector v
cp.Maximize(cp.sum(cp.log(w)))
# Out:
# Maximize(Expression(CONCAVE, UNKNOWN, ()))

# %% [markdown]
# #### Restricciones
# - **Definición**: Son las condiciones que las variables de decisión deben cumplir. Representadas por $f_i$.
# - **Ejemplo**: En un problema de minimización de costos, podría ser los costes mínimos necesarios para cada tarea.

# %% [markdown]
# - Las restricciones se modelan con expresiones de igualdad y desigualdad
# con ==, >=, <=.
#
# - Las desigualdades estrictas < y > no están permitidas. $x<5$ se sustituye por $x+\epsilon \leq 5$ siendo $\epsilon$ un número muy pequeño
#
# - Las expresiones de desigualdad se interpretan elemento a elemento y sigiuendo
# las reglas de interpretación para escalares, vectores y matrices al estilo
# de numpy (broadcasting).

# %%
# los 5 elementos del vector v debe ser mayor que 6
w <= 6
# Out:
# Inequality(Variable((5,), var2))

# %%
# Cada elemento de v debe ser mayor que cada elemento del array c
c = np.array([1, 3, 5, 10, 2])
w >= c
# Out:
# Inequality(Constant(CONSTANT, NONNEGATIVE, (5,)))

# %%
# Las expresiones las podemos asignar a variables o agruparlas en listas
restriccion_1 = m <= 10
restriccion_2 = m >= 0
constraints = [restriccion_1, restriccion_2]
constraints.append(w <= c)
constraints
# Out:
# [Inequality(Variable((5, 2), var3)),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Variable((5,), var2))]

# %% [markdown]
# Si pensamos en que CVXPY está construido sobre numpy, podemos imaginar que es posible definir restricciones sobre subconjuntos de variables usando el indexado o el slicing:

# %%
# La variable m31 debe ser <= 9
m[3, 1] <= 9
# Out:
# Inequality(Expression(AFFINE, UNKNOWN, ()))

# %%
# Las variables de la primera columna de las 4 primeras filas deben ser <= 8
m[:4, 0] <= 8
# Out:
# Inequality(Expression(AFFINE, UNKNOWN, (4,)))

# %%
# Podemos mezclar nuestro código con la construcción
# de restricciones a nuestra conveniencia

other_constraints = []
for i in range(w.shape[0]):
    other_constraints.append(w[i] >= i - 2)

other_constraints
# Out:
# [Inequality(Constant(CONSTANT, NONPOSITIVE, ())),
#  Inequality(Constant(CONSTANT, NONPOSITIVE, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Constant(CONSTANT, NONNEGATIVE, ())),
#  Inequality(Constant(CONSTANT, NONNEGATIVE, ()))]

# %% [markdown]
# ### Operadores y Funciones
# La librería trata los operadores +, -, *, / y @ como funciones, conservando la semántica de numpy.

# %%
w * 2
# Out:
# Expression(AFFINE, UNKNOWN, (5,))

# %%
w + w * 2
# Out:
# Expression(AFFINE, UNKNOWN, (5,))

# %%
# w tiene shape (5,)
# m tiene shape (5,2)
w @ m  # tiene shape (2,)
# Out:
# Expression(UNKNOWN, UNKNOWN, (2,))

# %%
# m tiene shape (5,2)
# m.T tiene shape (2,5)
m @ m.T
# Out:
# Expression(UNKNOWN, UNKNOWN, (5, 5))

# %% [markdown]
# OJO: Algunas funciones se aplican a cada elemento, como en numpy:

# %%
# valor absoluto de cada elemento del vector
cp.abs(w)
# Out:
# Expression(CONVEX, NONNEGATIVE, (5,))

# %%
# para cada elemento de la matriz se calcula e^{m_ij}
cp.exp(m)
# Out:
# Expression(CONVEX, NONNEGATIVE, (5, 2))

# %% [markdown]
# La librería contiene un conjunto diverso de funciones para realizar
# la mayoría de los cálculos matemáticos.
#
# -  Consultar una lista mas completa en la [documentación](https://www.cvxpy.org/tutorial/functions/index.html)
